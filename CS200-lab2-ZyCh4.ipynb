# %% [markdown]
# # Lab 2 - Chapter 4 Zybooks - Loops

# %% [markdown]
# Instructions: This program is from 4.1.1 in your Zybook
#
# Modify the base program to create an interactive calculator.
#
# Your goals:
# - ask the user for input values
# - replace the constants with user input
# - improve the output
# - add one extra feature
#
# Complete each TODO section below. Do not delete the base program.

# %% [markdown]
# 1. Base Program. Run the program as is and see how it works.

# %%
##
#  This program computes the time required to double an investment.
#

# Create constant variables.
RATE = 5.0
INITIAL_BALANCE = 10000.0
TARGET = 2 * INITIAL_BALANCE

# Initialize variables used with the loop.
balance = INITIAL_BALANCE
year = 0

# Count the years required for the investment to double.
while balance < TARGET :
   year = year + 1
   interest = balance * RATE / 100
   balance = balance + interest

# Print the results.   
print("The investment doubled after", year, "years.")

# %% [markdown]
# 1. TODO 1: Ask the user for values

# %%
# TODO:
# 1. Ask the user to enter an initial balance and convert it to a float
# 2. Ask the user to enter an interest rate and convert it to a float

initial_balance = TODO
rate = TODO

print("Initial balance =", initial_balance)
print("Rate =", rate)

# %% [markdown]
# 2. TODO 2: Replace the constant values

# %%
# TODO:
# 1. Set the target to double the initial balance.
# 2. Set balance equal to the initial balance.
# 3. Set year equal to 0.

# Fill in the TODOs below.

target = 2 * TODO
balance = TODO
year = TODO

print("Target =", target)
print("Starting balance =", balance)
print("Starting year =", year)

# %% [markdown]
# 3. TODO 3: Run the while loop

# %%
# TODO:
# Use the same loop idea as the base program, but use:
# - target
# - balance
# - rate
# - year

while balance < target:
    year += 1
    interest = balance * rate / 100
    balance += interest

print("The investment doubled after", year, "years.")

# %% [markdown]
# 4. TODO 4: Improve the output look on the screen

# %%
# TODO:
# Improve the final print statement using an f-string.
# Include:
# - initial balance
# - interest rate
# - number of years

print(f"An investment of ${TODO:,.2f} at {TODO:.2f}% interest doubles in {TODO} years.")

# %% [markdown]
# 5. TODO 5: Ask user for a multiplier. Test the program with different multipliers to see how it changes the output.

# %%
# TODO:
# Ask the user for a multiplier.
# Example:
# 2 means double
# 3 means triple
# 4 means quadruple

multiplier = float(input("Enter a target multiplier (2 = double, 3 = triple, etc.): "))

target = initial_balance * multiplier
balance = initial_balance
year = 0

while balance < target:
    year += 1
    interest = balance * rate / 100
    balance += interest

print(f"It takes {year} years for ${initial_balance:,.2f} to grow to ${target:,.2f} at {rate:.2f}% interest.")

# %% [markdown]
# 6. Reflection

# %% [markdown]
# In 2-3 sentences, answer:
# 1. What parts of the chapter did you find most challenging?
# 2. What parts of the chapter do you think you can apply to your own major or interests?
